# %%
from matplotlib import rcParams
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import helpers as hl

# %%
reg = hl.registro_temas
[*reg.keys()]
# Out:
# ['blanco', 'catpuccin latte', 'cobalto']

# %%
hl.visualizar_tema('blanco');

# %%
hl.visualizar_tema('catpuccin latte');

# %%
hl.equivalent_gray('#F5F7FA')
# Out:
# '#f7f7f7'

# %%
hl.visualizar_tema('cobalto');

# %%
from matplotlib import colors as mcolors
mcolors.to_rgba('#fafd24')
# Out:
# (0.9803921568627451, 0.9921568627450981, 0.1411764705882353, 1.0)
